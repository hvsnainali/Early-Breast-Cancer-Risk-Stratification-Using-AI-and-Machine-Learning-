# %% [markdown]
# # Early Breast Cancer Prediction

# %%
#!pip install xgboost catboost

# %%
#%pip -q install tqdm tqdm-joblib

# %%
# %pip -q install lightgbm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1)Setup & Configuration

# %%
DATA_PATH = "sample_10percent.csv"   # Sample / Full dataset
TEST_SIZE = 0.2
SAMPLE_FRAC   = 0.10        # <-- set to 0.10 or 0.20 for quick runs
CV_FOLDS = 3
RANDOM_STATE = 42
N_JOBS = -1
#MAX_PLOT_ROWS = 50000

import sys, platform, importlib, warnings
warnings.filterwarnings("ignore")
print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline as SkPipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,
                             roc_curve, precision_recall_curve, average_precision_score, ConfusionMatrixDisplay, brier_score_loss)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier, HistGradientBoostingClassifier
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.metrics import (roc_auc_score, average_precision_score, f1_score,
                             precision_score, recall_score, confusion_matrix,
                             roc_curve, precision_recall_curve)

import matplotlib.pyplot as plt, seaborn as sns
sns.set(style="whitegrid"); plt.rcParams["figure.figsize"] = (7.5, 5)

from tqdm.auto import tqdm
from tqdm_joblib import tqdm_joblib
from sklearn.model_selection import ParameterGrid

try:
    from xgboost import XGBClassifier
    XGB_AVAILABLE = True
except Exception:
    XGB_AVAILABLE = False

pd.set_option("display.max_columns", 220)
pd.set_option("display.width", 220)


print("Config ready. DATA_PATH:", DATA_PATH, 'Yes' if XGB_AVAILABLE else 'No')
# Out:
# Python: 3.13.5
# Platform: macOS-15.6.1-arm64-arm-64bit-Mach-O
# Config ready. DATA_PATH: sample_10percent.csv Yes

# %% [markdown]
# ## 2) Load Data → `head()` / `info()` / dtypes

# %%
df = pd.read_csv(DATA_PATH)
print("Loaded shape:", df.shape)
# Out:
# Loaded shape: (152234, 13)

# %%
display(df.describe(include='number').T.head(30))
# Out:
#                           count         mean        std     min     25%     50%     75%     max
# year                   152234.0  2010.910881   3.657702  2005.0  2008.0  2011.0  2014.0  2017.0
# age_group_5_years      152234.0     7.311750   2.556376     1.0     5.0     7.0     9.0    13.0
# race_eth               152234.0     2.656023   2.271176     1.0     1.0     2.0     3.0     9.0
# first_degree_hx        152234.0     0.797962   2.088211     0.0     0.0     0.0     1.0     9.0
# age_menarche           152234.0     4.586781   4.045175     0.0     1.0     2.0     9.0     9.0
# age_first_birth        152234.0     3.538080   3.146185     0.0     1.0     3.0     4.0     9.0
# BIRADS_breast_density  152234.0     3.216975   2.259461     1.0     2.0     3.0     3.0     9.0
# current_hrt            152234.0     1.938181   3.612092     0.0     0.0     0.0     1.0     9.0
# menopaus               152234.0     2.641401   2.315366     1.0     2.0     2.0     2.0     9.0
# bmi_group              152234.0     4.254674   3.240942     1.0     2.0     3.0     9.0     9.0
# biophx                 152234.0     0.743395   1.789967     0.0     0.0     0.0     1.0     9.0
# breast_cancer_history  152234.0     2.109759   3.656681     0.0     0.0     0.0     1.0     9.0
# count                  152234.0     4.434548  17.485397     1.0     1.0     1.0     3.0  1469.0

# %%
rename_map = {
    "age_group_5_years": "age",
    "race_eth": "race",
    "first_degree_hx": "family_history",
    "age_menarche": "menarche",
    "age_first_birth": "first_birth",
    "BIRADS_breast_density": "breast",
    "current_hrt": "hormone_therapy",
    "menopaus": "menopause",
    "bmi_group": "bmi",
    "biophx": "biopsy",
    "breast_cancer_history": "cancer"
}

df = df.rename(columns=rename_map)

# %%
TARGET_COL = "cancer"  # Target Variable set
assert TARGET_COL in df.columns, f"TARGET_COL '{TARGET_COL}' not found — set it in the config above."
print("TARGET_COL:", TARGET_COL)
WEIGHT_COL = "count"
UNKNOWN = 9
# Out:
# TARGET_COL: cancer

# %%
df_numeric = df.select_dtypes(include=['number'])

plt.figure(figsize=(20,10))
sns.heatmap(df_numeric.corr(), annot=True)
# Out:
# <Axes: >

# %%
vc = df["cancer"].value_counts().sort_index()
print("Counts:\n", vc)
print("\nPercentages:\n", (vc / len(df) * 100).round(2))
# Out:
# Counts:
#  cancer
# 0    96833
# 1    22179
# 9    33222
# Name: count, dtype: int64
#
# Percentages:
#  cancer
# 0    63.61
# 1    14.57
# 9    21.82
# Name: count, dtype: float64

# %%
df = df[df["cancer"] != 9]
breast = df['breast'].astype('int64')
df['breast_dense_3lvl'] = (
    breast.replace({1:1, 2:1, 3:2, 4:2})
          .where(~breast.isin([9]), 9)
).astype('int64')
df['breast_dense_binary'] = df['breast_dense_3lvl'].replace({1:0, 2:1}).astype('int64')

# %%
# Age wide bins + midpoint
age = df['age'].astype('Int64')
age_wide_map = {1:1,2:1,3:1, 4:2,5:2, 6:3,7:3, 8:4,9:4, 10:5,11:5, 12:6,13:6}
age_wide_labels = {1:'18-39',2:'40-49',3:'50-59',4:'60-69',5:'70-79',6:'80+'}
df['age_widebin_6lvl'] = age.map(age_wide_map).astype('int64')
df['age_widebin_6lvl_label'] = df['age_widebin_6lvl'].map(age_wide_labels)

age_mid = {1:23.5,2:32.0,3:37.0,4:42.0,5:47.0,6:52.0,7:57.0,8:62.0,9:67.0,10:72.0,11:77.0,12:82.0,13:87.0}
df['age_proxy'] = age.map(age_mid).astype(float)

# BMI midpoint proxy
bmi = df['bmi'].astype('int64')
bmi_mid = {1:22.5, 2:27.5, 3:32.5, 4:37.5, 9:np.nan}
df['bmi_proxy'] = bmi.map(bmi_mid).astype(float)

# %%
df['postmeno_dense'] = np.where(
    (df['menopause'] == 2) & (df['breast_dense_binary'] == 1), 1,
    np.where(
        df['menopause'].isin([1,2]) & df['breast_dense_binary'].isin([0,1]), 0, np.nan
    )
).astype('int64')

# %%
df['menopause'].unique()
# Out:
# array([2, 9, 1, 3])

# %%
fh = df['family_history'].astype('int64')
bx = df['biopsy'].astype('int64')
df['fam_or_biopsy'] = np.where(
    (fh == 1) | (bx == 1), 1,
    np.where(fh.isin([0,1]) & bx.isin([0,1]), 0, np.nan)
).astype('int64')

# Estrogen exposure window (longer -> higher risk)
df["age_menarche_gap"] = (df["age"] - df["menarche"]).clip(lower=0)

# Nulliparity & years since first birth (if 'first_birth' is age at first live birth; 0/neg = none)
df["nulliparous"] = (df["first_birth"] <= 0).astype(int)
df["years_since_first_birth"] = np.where(df["first_birth"] > 0,
                                         (df["age_proxy"] - df["first_birth"]).clip(lower=0),
                                         np.nan)
# Density interactions
df["density_x_famhx"] = df["breast_dense_binary"] * df["family_history"]
df["density_x_postmeno"] = df["breast_dense_binary"] * (df["menopause"] == 1)

# Missingness is information
df["is_bmi_missing"] = df["bmi_proxy"].isna().astype(int)

# %%
# Simple polynomials
for col in ['year','age_proxy','bmi_proxy']:
    if col in df.columns:
        df[f'{col}_sq'] = df[col]**2
if set(['year','age_proxy']).issubset(df.columns):
    df['year_x_age'] = df['year'] * df['age_proxy']
if set(['year','bmi_proxy']).issubset(df.columns):
    df['year_x_bmi'] = df['year'] * df['bmi_proxy']
if set(['age_proxy','bmi_proxy']).issubset(df.columns):
    df['age_x_bmi'] = df['age_proxy'] * df['bmi_proxy']


# ---------------------------------------------------------------------------
print( " ✓ Engineered columns added ✓ " )
display(df.filter([
    'breast','age_menarche_gap','years_since_first_birth','nulliparous','breast_dense_3lvl','breast_dense_binary',
    'menopause_3lvl','menopause_label',
    'age','age_widebin_6lvl','age_widebin_6lvl_label','age_proxy',
    'bmi','is_bmi_missing,''bmi_proxy','years_since_first_birth','density_x_postmeno','postmeno_dense','fam_or_biopsy','density_x_famhx',
]).sample(8))

# ---------------------------------------------------------------------------
# Out:
#  ✓ Engineered columns added ✓
#         breast  age_menarche_gap  years_since_first_birth  nulliparous  breast_dense_3lvl  breast_dense_binary  age  age_widebin_6lvl age_widebin_6lvl_label  age_proxy  bmi  density_x_postmeno  postmeno_dense  \
# 41517        3                 4                     50.0            0                  2                    1    6                 3                  50-59       52.0    2                   0               1
# 1997         2                 3                     39.0            0                  1                    0    4                 2                  40-49       42.0    2                   0               0
# 106929       2                 0                     40.0            0                  1                    0    4                 2                  40-49       42.0    1                   0               0
# 87752        2                 0                      NaN            1                  1                    0    4                 2                  40-49       42.0    4                   0               0
# 136879       2                 2                     76.0            0                  1                    0   11                 5                  70-79       77.0    1                   0               0
# 106647       1                 3                     80.0            0                  1                    0   12                 6                    80+       82.0    3                   0               0
# 62299        4                 4                     40.0            0                  2                    1    4                 2                  40-49       42.0    2                   1               0
# 40665        3                 5                     48.0            0                  2                    1    7                 3                  50-59       57.0    2                   0               1
#
#         fam_or_biopsy  density_x_famhx
# 41517               1                1
# 1997                1                0
# 106929              0                0
# 87752               0                0
# 136879              1                0
# 106647              1                0
# 62299               1                0
# 40665               1                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119012 entries, 1 to 152233
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     119012 non-null  int64
#  1   age                      119012 non-null  int64
#  2   race                     119012 non-null  int64
#  3   family_history           119012 non-null  int64
#  4   menarche                 119012 non-null  int64
#  5   first_birth              119012 non-null  int64
#  6   breast                   119012 non-null  int64
#  7   hormone_therapy          119012 non-null  int64
#  8   menopause                119012 non-null  int64
#  9   bmi                      119012 non-null  int64
#  10  biopsy                   119012 non-null  int64
#  11  cancer                   119012 non-null  int64
#  12  count                    119012 non-null  int64
#  13  breast_dense_3lvl        119012 non-null  int64
#  14  breast_dense_binary      119012 non-null  int64
#  15  age_widebin_6lvl         119012 non-null  int64
#  16  age_widebin_6lvl_label   119012 non-null  object
#  17  age_proxy                119012 non-null  float64
#  18  bmi_proxy                88154 non-null   float64
#  19  postmeno_dense           119012 non-null  int64
#  20  fam_or_biopsy            119012 non-null  int64
#  21  age_menarche_gap         119012 non-null  int64
#  22  nulliparous              119012 non-null  int64
#  23  years_since_first_birth  100478 non-null  float64
#  24  density_x_famhx          119012 non-null  int64
#  25  density_x_postmeno       119012 non-null  int64
#  26  is_bmi_missing           119012 non-null  int64
#  27  year_sq                  119012 non-null  int64
#  28  age_proxy_sq             119012 non-null  float64
#  29  bmi_proxy_sq             88154 non-null   float64
#  30  year_x_age               119012 non-null  float64
#  31  year_x_bmi               88154 non-null   float64
#  32  age_x_bmi                88154 non-null   float64
# dtypes: float64(8), int64(24), object(1)
# memory usage: 30.9+ MB

# %%
# ---------------------------------------------------------------------------
#    bmi_proxy HAVE MISSING?
#    Because bmi=9 (Unknown) -> NaN *only on the numeric proxy* by design.
# ---------------------------------------------------------------------------
bmi_unknown_cnt = int((df['bmi'] == 9).sum())
bmi_proxy_nan_cnt = int(df['bmi_proxy'].isna().sum())
print(f"bmi==9 (Unknown) rows: {bmi_unknown_cnt}")
print(f"bmi_proxy NaNs     : {bmi_proxy_nan_cnt}  (should match)")

# Weighted BMI prevalence
w = df['count'] if 'count' in df.columns else 1
bmi_tab = pd.crosstab(df['bmi'], df['cancer'], values=w, aggfunc='sum', normalize='index')\
            .rename(columns={0:'no_cancer',1:'cancer'})\
            .reindex([1,2,3,4,9])
print("\nWeighted cancer prevalence by BMI group:")
display(bmi_tab.round(3))

ax = bmi_tab['cancer'].plot(kind='bar', title='Weighted cancer prevalence by BMI group')
ax.set_xlabel('bmi (1..4; 9=unknown)')
ax.set_ylabel('prevalence')
plt.show()
# Out:
# bmi==9 (Unknown) rows: 30858
# bmi_proxy NaNs     : 30858  (should match)
#
# Weighted cancer prevalence by BMI group:
# cancer  no_cancer  cancer
# bmi
# 1           0.926   0.074
# 2           0.920   0.080
# 3           0.927   0.073
# 4           0.933   0.067
# 9           0.888   0.112

# %%
# Breast density
prev_breast = pd.crosstab(df['breast_dense_3lvl'], df['cancer'], values=w, aggfunc='sum', normalize='index')\
                .rename(columns={0:'no_cancer',1:'cancer'})
print("Breast density (3lvl) -> cancer prevalence:")
display(prev_breast.round(3))
ax = prev_breast['cancer'].plot(kind='bar', title='Cancer prevalence by breast density (weighted)')
ax.set_xlabel('1=non-dense, 2=dense, 9=unknown')
ax.set_ylabel('prevalence')
plt.show()
# Out:
# Breast density (3lvl) -> cancer prevalence:
# cancer             no_cancer  cancer
# breast_dense_3lvl
# 1                      0.905   0.095
# 2                      0.927   0.073
# 9                      0.901   0.099

# %%
# Menopause
prev_meno = pd.crosstab(df['menopause'], df['cancer'], values=w, aggfunc='sum', normalize='index')\
             .rename(columns={0:'no_cancer',1:'cancer'})
print("Menopause -> cancer prevalence:")
display(prev_meno.round(3))
ax = prev_meno['cancer'].plot(kind='bar', title='Cancer prevalence by menopause (weighted)')
ax.set_xlabel('menopause')
ax.set_ylabel('prevalence')
plt.show()

# Age wide bins
prev_age = pd.crosstab(df['age_widebin_6lvl_label'], df['cancer'], values=w, aggfunc='sum', normalize='index')\
            .rename(columns={0:'no_cancer',1:'cancer'})\
            .reindex(['18-39','40-49','50-59','60-69','70-79','80+'])
print("Age (wide bins) -> cancer prevalence:")
display(prev_age.round(3))
ax = prev_age['cancer'].plot(kind='bar', title='Cancer prevalence by age (weighted)')
ax.set_xlabel('age group')
ax.set_ylabel('prevalence')
plt.show()
# Out:
# Menopause -> cancer prevalence:
# cancer     no_cancer  cancer
# menopause
# 1              0.973   0.027
# 2              0.885   0.115
# 3              0.948   0.052
# 9              0.889   0.111
# Age (wide bins) -> cancer prevalence:
# cancer                  no_cancer  cancer
# age_widebin_6lvl_label
# 18-39                       0.970   0.030
# 40-49                       0.972   0.028
# 50-59                       0.938   0.062
# 60-69                       0.895   0.105
# 70-79                       0.841   0.159
# 80+                         0.728   0.272

# %%
df["biopsy_yes"] = (df["biopsy"] == 1).astype(int)     # 1 if biopsy==1 else 0
df["biopsy_unk"] = (df["biopsy"] == 9).astype(int)     # 1 if biopsy==9 else 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119012 entries, 1 to 152233
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   year                     119012 non-null  int64
#  1   age                      119012 non-null  int64
#  2   race                     119012 non-null  int64
#  3   family_history           119012 non-null  int64
#  4   menarche                 119012 non-null  int64
#  5   first_birth              119012 non-null  int64
#  6   breast                   119012 non-null  int64
#  7   hormone_therapy          119012 non-null  int64
#  8   menopause                119012 non-null  int64
#  9   bmi                      119012 non-null  int64
#  10  biopsy                   119012 non-null  int64
#  11  cancer                   119012 non-null  int64
#  12  count                    119012 non-null  int64
#  13  breast_dense_3lvl        119012 non-null  int64
#  14  breast_dense_binary      119012 non-null  int64
#  15  age_widebin_6lvl         119012 non-null  int64
#  16  age_widebin_6lvl_label   119012 non-null  object
#  17  age_proxy                119012 non-null  float64
#  18  bmi_proxy                88154 non-null   float64
#  19  postmeno_dense           119012 non-null  int64
#  20  fam_or_biopsy            119012 non-null  int64
#  21  age_menarche_gap         119012 non-null  int64
#  22  nulliparous              119012 non-null  int64
#  23  years_since_first_birth  100478 non-null  float64
#  24  density_x_famhx          119012 non-null  int64
#  25  density_x_postmeno       119012 non-null  int64
#  26  is_bmi_missing           119012 non-null  int64
#  27  year_sq                  119012 non-null  int64
#  28  age_proxy_sq             119012 non-null  float64
#  29  bmi_proxy_sq             88154 non-null   float64
#  30  year_x_age               119012 non-null  float64
#  31  year_x_bmi               88154 non-null   float64
#  32  age_x_bmi                88154 non-null   float64
#  33  biopsy_yes               119012 non-null  int64
#  34  biopsy_unk               119012 non-null  int64
# dtypes: float64(8), int64(26), object(1)
# memory usage: 32.7+ MB

# %%
if 0 < SAMPLE_FRAC < 1:
    df = (df
          .groupby(TARGET_COL, group_keys=False)
          .apply(lambda x: x.sample(frac=SAMPLE_FRAC, random_state=RANDOM_STATE))
          .reset_index(drop=True))
    print(f"Using stratified sample: {len(df):,} rows (frac={SAMPLE_FRAC:.0%})")
else:
    print("SAMPLE_FRAC not in (0,1); using full dataset.")
# Out:
# Using stratified sample: 11,901 rows (frac=10%)

# %% [markdown]
# ### CAT / NUM cols

# %%
DROP_COLS= ["age_widebin_6lvl_label"]
# CATEGORICAL codes
CATEGORICAL_COLS = ["race","family_history","menarche","first_birth",
            "menopause","breast","biopsy","hormone_therapy","age_widebin_6lvl","breast_dense_3lvl"]


# NUMERIC  
NUMERIC_COLS = ["year","age_proxy","bmi_proxy",
            "year_sq","bmi","age_proxy_sq","bmi_proxy_sq",
            "year_x_age","year_x_bmi","age_x_bmi",
            "biopsy_yes","biopsy_unk",
            "age_menarche_gap", "nulliparous", "years_since_first_birth",
            "density_x_famhx", "density_x_postmeno", "is_bmi_missing",
            "breast_dense_binary","postmeno_dense","fam_or_biopsy"]

assert TARGET_COL in df.columns, f"Missing target: {TARGET_COL}"
assert WEIGHT_COL in df.columns, f"Missing weight column: {WEIGHT_COL}"
missing_in_df = [c for c in CATEGORICAL_COLS if c not in df.columns]
assert not missing_in_df, f"Missing categorical columns: {missing_in_df}"

# %%
print(f"Numeric features: {len(NUMERIC_COLS)} | Categorical features: {len(CATEGORICAL_COLS)}")
# Out:
# Numeric features: 21 | Categorical features: 10

# %%
missing_in_df
# Out:
# []

# %%
# Loading Bar
QUIET = True
SEARCH_VERBOSE = 0 if QUIET else 2
EST_VERBOSE    = 0 if QUIET else 1

def fit_with_progress(name, search, X, y, fit_kwargs=None, cv=None, grid=None):
    fit_kwargs = fit_kwargs or {}
    total = None
    if grid is not None and cv is not None:
        total = len(list(ParameterGrid(grid))) * cv.get_n_splits()
    pbar = tqdm(total=total, desc=f"{name} grid", unit="fit", leave=True, dynamic_ncols=True)
    with tqdm_joblib(pbar):
        result = search.fit(X, y, **fit_kwargs)
    pbar.close()
    return result

# %% [markdown]
# ## Train Test SPLIT - Preprocessing

# %%
X = df.drop(columns=[TARGET_COL])
y = df[TARGET_COL].astype(int)
W = df[WEIGHT_COL].astype(float)

# %%
numeric_tf = SkPipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_tf = SkPipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_tf, NUMERIC_COLS),
        ("cat", categorical_tf, CATEGORICAL_COLS),
    ],
    remainder="drop",
    verbose_feature_names_out=False
)

# %%
X_train, X_test, y_train, y_test, W_train, W_test = train_test_split(
    X, y, W, test_size=TEST_SIZE, stratify=y, random_state=RANDOM_STATE
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape, W_train.shape, W_test.shape
# Out:
# ((9520, 34), (2381, 34), (9520,), (2381,), (9520,), (2381,))

# %%
sns.set(style="whitegrid"); plt.rcParams["figure.figsize"] = (7.5, 5)
cv = StratifiedKFold(n_splits=CV_FOLDS, shuffle=True, random_state=RANDOM_STATE)

def specificity_score(y_true, y_pred, sample_weight=None):
    cm = confusion_matrix(y_true, y_pred, sample_weight=sample_weight)
    tn, fp, fn, tp = cm.ravel()
    return float(tn) / (tn + fp) if (tn + fp) > 0 else 0.0

def npv_score(y_true, y_pred, sample_weight=None):
    cm = confusion_matrix(y_true, y_pred, sample_weight=sample_weight)
    tn, fp, fn, tp = cm.ravel()
    return float(tn) / (tn + fn) if (tn + fn) > 0 else 0.0

def eval_on_test(name, est, Xt, yt, w=None, thr=0.5):
    proba = est.predict_proba(Xt)[:, 1]
    yhat = (proba >= thr).astype(int)
    cm = confusion_matrix(yt, yhat, sample_weight=w)
    acc = cm.trace() / cm.sum()
    return {
        "model": name,
        "threshold": thr,
        "accuracy": acc,
        "precision": precision_score(yt, yhat, sample_weight=w, zero_division=0),
        "recall": recall_score(yt, yhat, sample_weight=w, zero_division=0),
        "f1": f1_score(yt, yhat, sample_weight=w, zero_division=0),
        "specificity": specificity_score(yt, yhat, sample_weight=w),
        "npv": npv_score(yt, yhat, sample_weight=w),
        "roc_auc": roc_auc_score(yt, proba, sample_weight=w),
        "pr_auc": average_precision_score(yt, proba, sample_weight=w)
    }

def plot_quick_diagnostics(name, est, Xt, yt, w=None, thr=0.5):
    proba = est.predict_proba(Xt)[:, 1]
    yhat = (proba >= thr).astype(int)

    cm = confusion_matrix(yt, yhat, sample_weight=w)
    sns.heatmap(cm, annot=True, fmt=".0f", cmap="Blues")
    plt.title(f"{name} — Confusion Matrix @ {thr:.2f}")
    plt.xlabel("Predicted"); plt.ylabel("Actual"); plt.show()

    fpr, tpr, _ = roc_curve(yt, proba, sample_weight=w)
    auc = roc_auc_score(yt, proba, sample_weight=w)
    plt.plot(fpr, tpr, lw=2, label=f"AUC = {auc:.3f}")
    plt.plot([0,1],[0,1],"--", lw=1); plt.title(f"{name} — ROC Curve")
    plt.xlabel("FPR"); plt.ylabel("TPR"); plt.legend(); plt.show()

    prec, rec, _ = precision_recall_curve(yt, proba, sample_weight=w)
    ap = average_precision_score(yt, proba, sample_weight=w)
    plt.plot(rec, prec, lw=2, label=f"AP = {ap:.3f}")
    plt.title(f"{name} — Precision–Recall Curve")
    plt.xlabel("Recall"); plt.ylabel("Precision"); plt.legend(); plt.show()

# %%
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
try:
    from xgboost import XGBClassifier
    XGB_AVAILABLE = True
except Exception:
    XGB_AVAILABLE = False
try:
    from catboost import CatBoostClassifier
    CAT_AVAILABLE = True
except Exception:
    CAT_AVAILABLE = False

# %% [markdown]
# # Model Building ----

# %% [markdown]
# ### LogR

# %%
from sklearn.model_selection import GridSearchCV, ParameterGrid
from sklearn.exceptions import ConvergenceWarning


logreg_pipe = SkPipeline(steps=[
    ("preprocess", preprocessor),
    ("clf", LogisticRegression(
        solver="liblinear",
        max_iter=200,      
        tol=1e-3,          # consider 5e-4 or 1e-3 if you want even faster
        verbose=EST_VERBOSE
    ))
])

# If you want to be methodologically clean with explicit sample weights:
logreg_grid = {
    "clf__penalty": ["l1", "l2"],
    "clf__C": np.logspace(-3, 3, 9),
    "clf__class_weight": [None]  
}


logreg_search = GridSearchCV(
    estimator=logreg_pipe,
    param_grid=logreg_grid,
    scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
    refit="pr_auc",
    cv=cv,
    n_jobs=-1,     # set to 1 if you want cleaner, ordered console logs
    verbose=SEARCH_VERBOSE
)

# %%
fit_with_progress("LR", logreg_search, X_train, y_train,
                  fit_kwargs={"clf__sample_weight": W_train},
                  cv=cv, grid=logreg_grid)

logreg_best = logreg_search.best_estimator_
print("Converged in iterations (best):", logreg_best.named_steps["clf"].n_iter_)
# Out:
# LR grid:   0%|          | 0/54 [00:00<?, ?fit/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Converged in iterations (best): [6]

# %%
logreg_best = logreg_search.best_estimator_
logreg_best_params = logreg_search.best_params_
print("LR best params:", logreg_best_params)

lr_res = eval_on_test("LogisticRegression", logreg_best, X_test, y_test, w=W_test)
pd.DataFrame([lr_res]); plot_quick_diagnostics("LogisticRegression", logreg_best, X_test, y_test, w=W_test)
# Out:
# LR best params: {'clf__C': np.float64(0.03162277660168379), 'clf__class_weight': None, 'clf__penalty': 'l2'}

# %%
lr_res = eval_on_test("LogisticRegression", logreg_best, X_test, y_test, w=W_test, thr=0.20)
display(pd.DataFrame([lr_res]))
# Out:
#                 model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 0  LogisticRegression        0.2  0.831161   0.247133  0.696767  0.364857     0.841214  0.973743  0.860341  0.359848

# %% [markdown]
# ### GB _ hgb BEST

# %%
gb_pipe = SkPipeline([
    ("preprocess", preprocessor),
    ("clf", GradientBoostingClassifier(random_state=42))
])

gb_grid = {
    "clf__n_estimators": [400,600],
    "clf__learning_rate": [0.05, 0.1],
    "clf__max_depth": [3, 5],
    "clf__subsample": [0.8, 1.0]
}
gb_search = GridSearchCV(
    gb_pipe, gb_grid,
    scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
    refit="pr_auc", cv=cv, n_jobs=-1, verbose=0
)

fit_with_progress("GB", gb_search, X_train, y_train,
                  fit_kwargs={"clf__sample_weight": W_train},
                  cv=cv, grid=gb_grid)
# Out:
# GB grid:   0%|          | 0/48 [00:00<?, ?fit/s]
#   0%|          | 0/48 [00:00<?, ?it/s]
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['year',
#                                                                           'age_proxy',
#                                                                           'bmi_proxy',
#                                                                           'year_sq',
#                                                                           'bmi',
#                                                                           'age_proxy_sq',
#                                                                           'bmi_proxy_sq',
#                                                                           'year_x_age',
#                                                                           'year_x_bmi',
#                                                                           'ag...
#                                                                           'hormone_therapy',
#                                                                           'age_widebin_6lvl',
#                                                                           'breast_dense_3lvl'])],
#                                                           verbose_feature_names_out=False)),
#                                        ('clf',
#                                         GradientBoostingClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'clf__learning_rate': [0.05, 0.1],
#                          'clf__max_depth': [3, 5],
#                          'clf__n_estimators': [400, 600],
#                          'clf__subsample': [0.8, 1.0]},
#              refit='pr_auc',
#              scoring={'f1': 'f1', 'pr_auc': 'average_precision',
#                       'roc_auc': 'roc_auc'})

# %%
gb_best = gb_search.best_estimator_
gb_best_params = gb_search.best_params_
print("GB best params:", gb_best_params)
# Out:
# GB best params: {'clf__learning_rate': 0.05, 'clf__max_depth': 3, 'clf__n_estimators': 400, 'clf__subsample': 0.8}

# %%
gb_res = eval_on_test("GradBoost", gb_best, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([gb_res]))
# Out:
#        model  threshold  accuracy  precision    recall        f1  specificity      npv   roc_auc    pr_auc
# 0  GradBoost        0.5  0.926909   0.450331  0.227425  0.302222     0.979234  0.94427  0.870859  0.337301

# %%
hgb_pipe = SkPipeline([
    ("preprocess", preprocessor),
    ("clf", HistGradientBoostingClassifier(random_state=42))
])

hgb_grid = {
    "clf__learning_rate": [0.05, 0.1],
    "clf__max_iter": [200, 400],
    "clf__max_depth": [None, 3, 5],
    "clf__l2_regularization": [0.0, 1.0],
    "clf__max_bins": [255]
}

hgb_search = GridSearchCV(
    hgb_pipe, hgb_grid,
    scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
    refit="pr_auc", cv=cv, n_jobs=-1, verbose=0
)

fit_with_progress("HGB", hgb_search, X_train, y_train, fit_kwargs={"clf__sample_weight": W_train}, cv=cv, grid=hgb_grid)
# Out:
# HGB grid:   0%|          | 0/72 [00:00<?, ?fit/s]
#   0%|          | 0/72 [00:00<?, ?it/s]
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['year',
#                                                                           'age_proxy',
#                                                                           'bmi_proxy',
#                                                                           'year_sq',
#                                                                           'bmi',
#                                                                           'age_proxy_sq',
#                                                                           'bmi_proxy_sq',
#                                                                           'year_x_age',
#                                                                           'year_x_bmi',
#                                                                           'ag...
#                                                                           'breast_dense_3lvl'])],
#                                                           verbose_feature_names_out=False)),
#                                        ('clf',
#                                         HistGradientBoostingClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'clf__l2_regularization': [0.0, 1.0],
#                          'clf__learning_rate': [0.05, 0.1],
#                          'clf__max_bins': [255], 'clf__max_depth': [None, 3, 5],
#                          'clf__max_iter': [200, 400]},
#              refit='pr_auc',
#              scoring={'f1': 'f1', 'pr_auc': 'average_precision',
#                       'roc_auc': 'roc_auc'})

# %%
hgb_best = hgb_search.best_estimator_
hgb_best_params = hgb_search.best_params_
print("HGB best params:", hgb_best_params)

hgb_res = eval_on_test("HistGradBoost", hgb_best, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([hgb_res]))
# Out:
# HGB best params: {'clf__l2_regularization': 1.0, 'clf__learning_rate': 0.05, 'clf__max_bins': 255, 'clf__max_depth': 3, 'clf__max_iter': 200}
#            model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc   pr_auc
# 0  HistGradBoost        0.5  0.924271   0.413943  0.211817  0.280236     0.977567  0.943117  0.872083  0.31052

# %% [markdown]
# ### Rr MODEL BEST

# %%
# Random Forest

# %%
rf_pipe = SkPipeline([
    ("preprocess", preprocessor),
    ("clf", RandomForestClassifier(random_state=42, n_jobs=-1))
])

rf_grid = {
    "clf__n_estimators": [400, 800],
    "clf__max_depth": [None, 10, 20],
    "clf__min_samples_split": [2, 5],
    "clf__min_samples_leaf": [1, 2],
    "clf__max_features": ["sqrt", 0.5],
    "clf__class_weight": [None, "balanced"]
}

rf_search = GridSearchCV(
    rf_pipe, rf_grid,
    scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
    refit="pr_auc", cv=cv, n_jobs=-1, verbose=0
)

fit_with_progress("RF", rf_search, X_train, y_train, fit_kwargs={"clf__sample_weight": W_train}, cv=cv, grid=rf_grid)

rf_best = rf_search.best_estimator_
rf_best_params = rf_search.best_params_
print("RF best params:", rf_best_params)

rf_res = eval_on_test("RandomForest", rf_best, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([rf_res]))
# Out:
# RF grid:   0%|          | 0/288 [00:00<?, ?fit/s]
#   0%|          | 0/288 [00:00<?, ?it/s]
# RF best params: {'clf__class_weight': None, 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 5, 'clf__n_estimators': 800}
#           model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 0  RandomForest        0.5  0.936142    0.67619  0.158305  0.256549     0.994329  0.940448  0.870344  0.358397

# %% [markdown]
# ### xgb + catbOOST

# %%
xgb_pipe = SkPipeline([
        ("preprocess", preprocessor),
        ("clf", XGBClassifier(
        objective="binary:logistic", eval_metric="logloss",
        n_estimators=400, tree_method="hist",
        random_state=42, n_jobs=-1, use_label_encoder=False, verbosity=0
        ))
])

xgb_grid = {
        "clf__max_depth": [3, 5, 7],
        "clf__learning_rate": [0.03, 0.1],
        "clf__subsample": [0.8, 1.0],
        "clf__colsample_bytree": [0.6, 0.8, 1.0],
        "clf__min_child_weight": [1,3, 5],
        "clf__reg_lambda": [0.0, 1.0, 5.0]
}

xgb_search = GridSearchCV(
        xgb_pipe, xgb_grid,
        scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
        refit="pr_auc", cv=cv, n_jobs=-1, verbose=0
)

fit_with_progress("XGB", xgb_search, X_train, y_train, fit_kwargs={"clf__sample_weight": W_train}, cv=cv, grid=xgb_grid)

xgb_best = xgb_search.best_estimator_
xgb_best_params = xgb_search.best_params_
print("XGB best params:", xgb_best_params)

xgb_res = eval_on_test("XGBoost", xgb_best, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([xgb_res]))
# Out:
# XGB grid:   0%|          | 0/972 [00:00<?, ?fit/s]
#   0%|          | 0/972 [00:00<?, ?it/s]
# XGB best params: {'clf__colsample_bytree': 0.6, 'clf__learning_rate': 0.03, 'clf__max_depth': 3, 'clf__min_child_weight': 1, 'clf__reg_lambda': 5.0, 'clf__subsample': 1.0}
#      model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 0  XGBoost        0.5  0.924348   0.415217  0.212932  0.281503     0.977567  0.943193  0.871885  0.323971

# %%
try:
    from catboost import CatBoostClassifier
    CAT_AVAILABLE = True
except Exception as e:
    CAT_AVAILABLE = False
    print("CatBoost not available — skipping.", e)

if CAT_AVAILABLE:
        cat_pipe = SkPipeline([
            ("preprocess", preprocessor),  # OHE already applied; OK
            ("clf", CatBoostClassifier(
                loss_function="Logloss", eval_metric="AUC",
                random_seed=42, verbose=False  # keep logs quiet
            ))
        ])
    
        cat_grid = {
            "clf__iterations": [500, 800],
            "clf__learning_rate": [0.03, 0.1],
            "clf__depth": [4, 6, 8],
            "clf__l2_leaf_reg": [1, 3, 5],
            "clf__subsample": [0.8, 1.0]
        }
    
        cat_search = GridSearchCV(
            cat_pipe, cat_grid,
            scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
            refit="pr_auc", cv=cv, n_jobs=-1, verbose=0
        )
    
        fit_with_progress("CAT", cat_search, X_train, y_train, fit_kwargs={"clf__sample_weight": W_train}, cv=cv, grid=cat_grid)
    
        cat_best = cat_search.best_estimator_
        cat_best_params = cat_search.best_params_
        print("CatBoost best params:", cat_best_params)
    
        cat_res = eval_on_test("CatBoost", cat_best, X_test, y_test, w=W_test, thr=0.5)
        display(pd.DataFrame([cat_res]))
# Out:
# CAT grid:   0%|          | 0/216 [00:00<?, ?fit/s]
#   0%|          | 0/216 [00:00<?, ?it/s]
# CatBoost best params: {'clf__depth': 4, 'clf__iterations': 500, 'clf__l2_leaf_reg': 1, 'clf__learning_rate': 0.03, 'clf__subsample': 0.8}
#       model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 0  CatBoost        0.5  0.927219   0.450363  0.207358  0.283969     0.981069  0.943006  0.874974  0.351163

# %% [markdown]
# ### svm MODEL

# %%
###

# %% [markdown]
# ### KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_pipe = SkPipeline([
    ("preprocess", preprocessor),
    ("clf", KNeighborsClassifier())
])

knn_grid = {
    "clf__n_neighbors": [5, 11, 21, 31],
    "clf__weights": ["uniform", "distance"],
    "clf__p": [1, 2]
}

knn_search = GridSearchCV(
    knn_pipe, knn_grid,
    scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
    refit="pr_auc", cv=cv, n_jobs=-1, verbose=0
)

fit_with_progress("KNN", knn_search, X_train, y_train, cv=cv, grid=knn_grid)  # no weights here

knn_best = knn_search.best_estimator_
knn_best_params = knn_search.best_params_
print("KNN best params:", knn_best_params)

knn_res = eval_on_test("KNN", knn_best, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([knn_res]))
# Out:
# KNN grid:   0%|          | 0/48 [00:00<?, ?fit/s]
#   0%|          | 0/48 [00:00<?, ?it/s]
# KNN best params: {'clf__n_neighbors': 31, 'clf__p': 1, 'clf__weights': 'distance'}
#   model  threshold  accuracy  precision    recall        f1  specificity       npv  roc_auc    pr_auc
# 0   KNN        0.5  0.905726   0.249211  0.176143  0.206401     0.960304  0.939693  0.83714  0.227168

# %% [markdown]
# ### Naive Bayes model

# %%
from sklearn.naive_bayes import GaussianNB

nb_pipe = SkPipeline([
    ("preprocess", preprocessor),
    ("clf", GaussianNB())
])

nb_grid = {"clf__var_smoothing": [1e-9, 1e-8, 1e-7]}

nb_search = GridSearchCV(
    nb_pipe, nb_grid,
    scoring={"pr_auc":"average_precision","roc_auc":"roc_auc","f1":"f1"},
    refit="pr_auc", cv=cv, n_jobs=-1, verbose=0
)

fit_with_progress("NB", nb_search, X_train, y_train, fit_kwargs={"clf__sample_weight": W_train}, cv=cv, grid=nb_grid)

nb_best = nb_search.best_estimator_
nb_best_params = nb_search.best_params_
print("NaiveBayes best params:", nb_best_params)

nb_res = eval_on_test("NaiveBayes", nb_best, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([nb_res]))
# Out:
# NB grid:   0%|          | 0/9 [00:00<?, ?fit/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
# NaiveBayes best params: {'clf__var_smoothing': 1e-07}
#         model  threshold  accuracy  precision    recall        f1  specificity       npv  roc_auc    pr_auc
# 0  NaiveBayes        0.5   0.80121   0.215967  0.705686  0.330721     0.808356  0.973486  0.83326  0.288609

# %%
all_results = []
pairs = [
    ("LogisticRegression", "logreg_best"),
    ("GradBoost", "gb_best"),
    ("HistGradBoost", "hgb_best"),
    ("XGBoost", "xgb_best") if "xgb_best" in globals() else None,
    ("CatBoost", "cat_best") if "cat_best" in globals() else None,
    ("KNN", "knn_best"),
    ("NaiveBayes", "nb_best"),
    ("RandomForest", "rf_best")
]
for p in pairs:
    if p is None: 
        continue
    name, var = p
    if var in globals():
        est = globals()[var]
        all_results.append(eval_on_test(name, est, X_test, y_test))

results_df = pd.DataFrame(all_results).sort_values("pr_auc", ascending=False)
display(results_df)
# Out:
#                 model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 1           GradBoost        0.5  0.826123   0.601351  0.200450  0.300676     0.969541  0.841021  0.800384  0.475669
# 4            CatBoost        0.5  0.826963   0.631148  0.173423  0.272085     0.976768  0.837539  0.801469  0.473555
# 0  LogisticRegression        0.5  0.822344   0.588235  0.157658  0.248668     0.974703  0.834660  0.796933  0.468227
# 3             XGBoost        0.5  0.825283   0.609375  0.175676  0.272727     0.974187  0.837550  0.802608  0.464493
# 2       HistGradBoost        0.5  0.822764   0.580882  0.177928  0.272414     0.970573  0.837416  0.798994  0.457677
# 7        RandomForest        0.5  0.822764   0.614583  0.132883  0.218519     0.980898  0.831510  0.790864  0.456902
# 5                 KNN        0.5  0.816464   0.523810  0.173423  0.260575     0.963862  0.835721  0.792716  0.429125
# 6          NaiveBayes        0.5  0.737925   0.368805  0.569820  0.447788     0.776458  0.887316  0.757816  0.361078

# %%
sns.barplot(data=results_df, x="pr_auc", y="model", orient="h")
plt.title("Model Comparison (PR-AUC)"); plt.xlabel("PR-AUC"); plt.ylabel(""); plt.show()

# %%
def choose_thresholds(est, Xt, yt, w=None,
                      target_recall=0.80, target_precision=0.50, beta=1.0):
    """
    Returns thresholds for best F-beta, recall ≥ target_recall, precision ≥ target_precision.
    Handles PR-curve shapes robustly (P/R are len N+1; thresholds are len N).
    """
    proba = est.predict_proba(Xt)[:, 1]
    P, R, T = precision_recall_curve(yt, proba, sample_weight=w)  # len(P)=len(R)=N+1, len(T)=N
    # Avoid divide-by-zero; compute F-beta for the first N points only (align with T)
    Pn, Rn = P[:-1], R[:-1]  # align with thresholds T
    F = (1 + beta**2) * Pn * Rn / (beta**2 * Pn + Rn + 1e-12)

    # best F-beta (choose argmax over aligned portion)
    i_f = int(np.nanargmax(F)) if F.size else 0
    thr_f = float(T[i_f]) if T.size else 0.5

    # recall ≥ target_recall  (R typically decreases with T; take the largest T that still meets it)
    idx_rec = np.where(Rn >= target_recall)[0]
    thr_rec = float(T[idx_rec[-1]]) if idx_rec.size else (float(T[0]) if T.size else 0.5)

    # precision ≥ target_precision (P often rises with T; take the smallest T that meets it)
    idx_pr = np.where(Pn >= target_precision)[0]
    thr_pr = float(T[idx_pr[0]]) if idx_pr.size else (float(T[-1]) if T.size else 1.0)

    # Clamp to [0,1] just in case
    thr_f   = float(np.clip(thr_f, 0.0, 1.0))
    thr_rec = float(np.clip(thr_rec, 0.0, 1.0))
    thr_pr  = float(np.clip(thr_pr, 0.0, 1.0))

    # Use consistent keys with two decimals for readability
    return {
        "bestF1": thr_f,
        f"recall≥{target_recall:.2f}": thr_rec,
        f"precision≥{target_precision:.2f}": thr_pr
    }

MODEL_VARS = {
    "LogisticRegression": "logreg_best",
    "GradBoost":          "gb_best",
    "HistGradBoost":      "hgb_best",
    "RandomForest":       "rf_best",
    "XGBoost":            "xgb_best",
    "CatBoost":           "cat_best",
    "SVM-RBF":            "svm_best",
    "KNN":                "knn_best",
    "NaiveBayes":         "nb_best",
}
available = {name: globals()[var] for name, var in MODEL_VARS.items() if var in globals()}

target_recall = 0.88
target_precision = 0.70

all_tables, thresholds_store = [], {}
for name, est in available.items():
    th = choose_thresholds(est, X_test, y_test, w=W_test,
                           target_recall=target_recall, target_precision=target_precision, beta=1.0)
    thresholds_store[name] = th

    rows = [
        eval_on_test(f"{name} @0.5", est, X_test, y_test, w=W_test, thr=0.5),
        eval_on_test(f"{name} @bestF1({th['bestF1']:.3f})", est, X_test, y_test, w=W_test, thr=th["bestF1"]),
        eval_on_test(f"{name} @rec≥{target_recall:.2f}({th[f'recall≥{target_recall:.2f}']:.3f})",
                     est, X_test, y_test, w=W_test, thr=th[f"recall≥{target_recall:.2f}"]),
        eval_on_test(f"{name} @prec≥{target_precision:.2f}({th[f'precision≥{target_precision:.2f}']:.3f})",
                     est, X_test, y_test, w=W_test, thr=th[f"precision≥{target_precision:.2f}"])
    ]
    all_tables.append(pd.DataFrame(rows))

ops_df = pd.concat(all_tables, ignore_index=True)
display(ops_df.sort_values(["model","threshold"]).reset_index(drop=True))
# Out:
#                                    model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 0                          CatBoost @0.5   0.500000  0.927219   0.450363  0.207358  0.283969     0.981069  0.943006  0.874974  0.351163
# 1                CatBoost @bestF1(0.262)   0.261752  0.894475   0.348197  0.591973  0.438481     0.917104  0.967790  0.874974  0.351163
# 2             CatBoost @prec≥0.70(0.653)   0.652744  0.935909   0.831776  0.099220  0.177291     0.998499  0.936781  0.874974  0.351163
# 3              CatBoost @rec≥0.88(0.060)   0.060143  0.739603   0.195593  0.880713  0.320097     0.729047  0.987908  0.874974  0.351163
# 4                         GradBoost @0.5   0.500000  0.926909   0.450331  0.227425  0.302222     0.979234  0.944270  0.870859  0.337301
# 5               GradBoost @bestF1(0.250)   0.250020  0.885940   0.322820  0.581940  0.415274     0.908682  0.966729  0.870859  0.337301
# 6            GradBoost @prec≥0.70(0.773)   0.772968  0.933814   0.782051  0.068004  0.125128     0.998582  0.934738  0.870859  0.337301
# 7             GradBoost @rec≥0.88(0.050)   0.050205  0.731300   0.190694  0.881828  0.313578     0.720040  0.987872  0.870859  0.337301
# 8                     HistGradBoost @0.5   0.500000  0.924271   0.413943  0.211817  0.280236     0.977567  0.943117  0.872083  0.310520
# 9           HistGradBoost @bestF1(0.341)   0.340990  0.910847   0.374751  0.420290  0.396217     0.947544  0.956236  0.872083  0.310520
# 10       HistGradBoost @prec≥0.70(0.821)   0.821496  0.931099   1.000000  0.010033  0.019868     1.000000  0.931051  0.872083  0.310520
# 11        HistGradBoost @rec≥0.88(0.052)   0.051648  0.738361   0.195122  0.882943  0.319613     0.727546  0.988107  0.872083  0.310520
# 12                              KNN @0.5   0.500000  0.905726   0.249211  0.176143  0.206401     0.960304  0.939693  0.837140  0.227168
# 13                    KNN @bestF1(0.318)   0.318231  0.850714   0.273489  0.691193  0.391909     0.862647  0.973920  0.837140  0.227168
# 14                 KNN @prec≥0.70(1.000)   1.000000  0.929857   0.000000  0.000000  0.000000     0.999416  0.930363  0.837140  0.227168
# 15                  KNN @rec≥0.88(0.180)   0.180147  0.645407   0.150523  0.881828  0.257152     0.627721  0.986113  0.837140  0.227168
# 16               LogisticRegression @0.5   0.500000  0.932573   0.539106  0.215162  0.307570     0.986240  0.943815  0.860341  0.359848
# 17     LogisticRegression @bestF1(0.251)   0.251385  0.879811   0.312212  0.604236  0.411698     0.900425  0.968167  0.860341  0.359848
# 18  LogisticRegression @prec≥0.70(0.695)   0.695400  0.933271   0.760563  0.060201  0.111570     0.998582  0.934228  0.860341  0.359848
# 19   LogisticRegression @rec≥0.88(0.049)   0.049255  0.721679   0.185454  0.884058  0.306592     0.709532  0.987924  0.860341  0.359848
# 20                       NaiveBayes @0.5   0.500000  0.801210   0.215967  0.705686  0.330721     0.808356  0.973486  0.833260  0.288609
# 21             NaiveBayes @bestF1(0.999)   0.999421  0.886328   0.308108  0.508361  0.383677     0.914603  0.961343  0.833260  0.288609
# 22          NaiveBayes @prec≥0.70(1.000)   1.000000  0.925978   0.311258  0.052397  0.089695     0.991327  0.933265  0.833260  0.288609
# 23           NaiveBayes @rec≥0.88(0.000)   0.000035  0.625388   0.143479  0.881828  0.246802     0.606205  0.985627  0.833260  0.288609
# 24                     RandomForest @0.5   0.500000  0.936142   0.676190  0.158305  0.256549     0.994329  0.940448  0.870344  0.358397
# 25           RandomForest @bestF1(0.246)   0.245851  0.860258   0.281008  0.646600  0.391760     0.876241  0.970713  0.870344  0.358397
# 26        RandomForest @prec≥0.70(0.518)   0.518220  0.936530   0.704663  0.151616  0.249541     0.995246  0.940055  0.870344  0.358397
# 27         RandomForest @rec≥0.88(0.101)   0.100607  0.750466   0.202921  0.882943  0.330000     0.740555  0.988314  0.870344  0.358397
# 28                          XGBoost @0.5   0.500000  0.924348   0.415217  0.212932  0.281503     0.977567  0.943193  0.871885  0.323971
# 29                XGBoost @bestF1(0.317)   0.317033  0.907200   0.369432  0.471572  0.414300     0.939788  0.959636  0.871885  0.323971
# 30             XGBoost @prec≥0.70(0.752)   0.751950  0.932263   0.800000  0.035674  0.068303     0.999333  0.932674  0.871885  0.323971
# 31              XGBoost @rec≥0.88(0.056)   0.055773  0.750854   0.202876  0.880713  0.329785     0.741139  0.988103  0.871885  0.323971

# %%
from sklearn.metrics import precision_recall_curve, roc_curve, average_precision_score, roc_auc_score
sns.set(style="whitegrid"); plt.rcParams["figure.figsize"] = (7.5, 5)

# pick top 4 by PR-AUC at threshold 0.5 (use your earlier results table if available)
base_rows = [eval_on_test(n, e, X_test, y_test, w=W_test, thr=0.5) for n,e in available.items()]
base_df = pd.DataFrame(base_rows).sort_values("pr_auc", ascending=False)
top4 = base_df["model"].head(4).tolist()

# PR overlay
plt.figure()
for name in top4:
    est = available[name]
    proba = est.predict_proba(X_test)[:,1]
    P, R, _ = precision_recall_curve(y_test, proba, sample_weight=W_test)
    ap = average_precision_score(y_test, proba, sample_weight=W_test)
    plt.plot(R, P, lw=2, label=f"{name} (AP={ap:.3f})")
plt.xlabel("Recall"); plt.ylabel("Precision"); plt.title("Precision–Recall (top 4)"); plt.legend(); plt.show()

# ROC overlay
plt.figure()
for name in top4:
    est = available[name]
    proba = est.predict_proba(X_test)[:,1]
    fpr, tpr, _ = roc_curve(y_test, proba, sample_weight=W_test)
    auc = roc_auc_score(y_test, proba, sample_weight=W_test)
    plt.plot(fpr, tpr, lw=2, label=f"{name} (AUC={auc:.3f})")
plt.plot([0,1],[0,1],"--", lw=1)
plt.xlabel("FPR"); plt.ylabel("TPR"); plt.title("ROC (top 4)"); plt.legend(); plt.show()

# %%
from sklearn.calibration import calibration_curve
import numpy as np

# pick best by PR-AUC at 0.5
best_name = base_df.iloc[0]["model"]; best_est = available[best_name]
print("Best by PR-AUC:", best_name)

# reliability curve
proba = best_est.predict_proba(X_test)[:,1]
prob_true, prob_pred = calibration_curve(y_test, proba, n_bins=10, strategy="quantile")
plt.plot(prob_pred, prob_true, marker="o"); plt.plot([0,1],[0,1],"--")
plt.xlabel("Predicted probability"); plt.ylabel("Observed frequency")
plt.title(f"Calibration — {best_name}"); plt.show()

# Optional: calibrate with isotonic on CV folds (re-fits model internally)
from sklearn.calibration import CalibratedClassifierCV
calib = CalibratedClassifierCV(estimator=best_est, method="isotonic", cv=3)
calib.fit(X_train, y_train, sample_weight=W_train)

# evaluate calibrated
calib_res = eval_on_test(f"{best_name} (calibrated)", calib, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([calib_res]))
# Out:
# Best by PR-AUC: LogisticRegression
#                              model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 0  LogisticRegression (calibrated)        0.5  0.924115   0.400978  0.182832  0.251149     0.979568  0.941261  0.845505  0.320427

# %%
import numpy as np, joblib
from dataclasses import dataclass

# pick top 3 by PR-AUC (from base_df computed above)
top3_names = base_df["model"].head(3).tolist()
top3_models = [available[n] for n in top3_names]
weights = base_df["pr_auc"].head(3).to_numpy()
weights = weights / weights.sum()

@dataclass
class SoftVotingEnsemble:
    models: list
    weights: np.ndarray
    def predict_proba(self, X):
        ps = [m.predict_proba(X)[:,1] for m in self.models]
        p = np.average(np.vstack(ps), axis=0, weights=self.weights)
        # return 2 columns to mimic predict_proba for binary
        return np.vstack([1-p, p]).T

ensemble = SoftVotingEnsemble(models=top3_models, weights=weights)
ens_res = eval_on_test("Ensemble(top3,weighted)", ensemble, X_test, y_test, w=W_test, thr=0.5)
display(pd.DataFrame([ens_res]))

# tune threshold for ensemble (e.g., best-F1)
from sklearn.metrics import precision_recall_curve
P,R,T = precision_recall_curve(y_test, ensemble.predict_proba(X_test)[:,1], sample_weight=W_test)
F = 2*P*R/(P+R+1e-12); thr_ens = float(T[int(np.nanargmax(F[:-1]))])
ens_res_tuned = eval_on_test(f"Ensemble @bestF1({thr_ens:.3f})", ensemble, X_test, y_test, w=W_test, thr=thr_ens)
display(pd.DataFrame([ens_res_tuned]))
# Out:
#                      model  threshold  accuracy  precision    recall        f1  specificity      npv   roc_auc    pr_auc
# 0  Ensemble(top3,weighted)        0.5  0.926055   0.427835  0.185061  0.258366     0.981486  0.94152  0.873569  0.365547
#                      model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 0  Ensemble @bestF1(0.247)   0.246919  0.874922   0.310746  0.654404  0.421393     0.891419  0.971816  0.873569  0.365547

# %%
from sklearn.metrics import precision_recall_curve
import numpy as np, pandas as pd, json
from pathlib import Path

outdir = Path("./best_models_no_smote_weights"); outdir.mkdir(parents=True, exist_ok=True)

def choose_threshold_for_recall(est, Xt, yt, w=None, target_recall=0.85):
    """Largest threshold that still achieves ≥ target_recall (best precision at that recall)."""
    proba = est.predict_proba(Xt)[:,1]
    P, R, T = precision_recall_curve(yt, proba, sample_weight=w)
    Pn, Rn = P[:-1], R[:-1]                 # align with T
    idx = np.where(Rn >= target_recall)[0]
    thr = float(T[idx[-1]]) if idx.size else float(T[0]) if T.size else 0.5
    return max(0.0, min(1.0, thr))

# Models you actually have (SVM removed)
MODEL_VARS = {
    "LogisticRegression": "logreg_best",
    "GradBoost":          "gb_best",
    "HistGradBoost":      "hgb_best",
    "RandomForest":       "rf_best",
    "XGBoost":            "xgb_best",
    "CatBoost":           "cat_best",
    "KNN":                "knn_best",
    "NaiveBayes":         "nb_best",
}
available = {name: globals()[var] for name, var in MODEL_VARS.items() if var in globals()}

targets = [0.65, 0.70, 0.80, 0.85, 0.90]
rows, th_store = [], {}

for name, est in available.items():
    th_store[name] = {}
    for t in targets:
        thr = choose_threshold_for_recall(est, X_test, y_test, w=W_test, target_recall=t)
        th_store[name][f"recall≥{t:.2f}"] = thr
        rows.append(eval_on_test(f"{name} @rec≥{t:.2f}({thr:.3f})", est, X_test, y_test, w=W_test, thr=thr))

ops_by_recall = pd.DataFrame(rows).sort_values(["threshold","precision"], ascending=[True,False])
display(ops_by_recall)

# Save thresholds (adds to/overwrites chosen_thresholds.json)
with open(outdir / "chosen_thresholds.json","w") as f:
    json.dump(th_store, f, indent=2)
print("Saved recall-targeted thresholds:", (outdir / "chosen_thresholds.json").resolve())
# Out:
#                                   model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 39          NaiveBayes @rec≥0.90(0.000)   0.000004  0.584342   0.133103  0.901895  0.231971     0.560587  0.987078  0.833260  0.288609
# 38          NaiveBayes @rec≥0.85(0.000)   0.000211  0.657433   0.151269  0.850613  0.256859     0.642982  0.982917  0.833260  0.288609
# 37          NaiveBayes @rec≥0.80(0.003)   0.002796  0.703988   0.164906  0.800446  0.273472     0.696773  0.979025  0.833260  0.288609
# 4   LogisticRegression @rec≥0.90(0.036)   0.036413  0.674969   0.164629  0.900780  0.278381     0.658077  0.988847  0.860341  0.359848
# 9            GradBoost @rec≥0.90(0.039)   0.038962  0.709885   0.181390  0.901895  0.302035     0.695522  0.989559  0.870859  0.337301
# 14       HistGradBoost @rec≥0.90(0.044)   0.044255  0.719662   0.186664  0.901895  0.309310     0.706030  0.989712  0.872083  0.310520
# 24             XGBoost @rec≥0.90(0.045)   0.045212  0.722688   0.188649  0.904125  0.312163     0.709115  0.989987  0.871885  0.323971
# 29            CatBoost @rec≥0.90(0.047)   0.047018  0.717412   0.185279  0.900780  0.307341     0.703694  0.989563  0.874974  0.351163
# 23             XGBoost @rec≥0.85(0.077)   0.077491  0.786235   0.225473  0.850613  0.356459     0.781419  0.985901  0.871885  0.323971
# 13       HistGradBoost @rec≥0.85(0.078)   0.078051  0.786701   0.225873  0.850613  0.356959     0.781920  0.985910  0.872083  0.310520
# 19        RandomForest @rec≥0.90(0.080)   0.080358  0.703600   0.178013  0.900780  0.297277     0.688850  0.989340  0.870344  0.358397
# 3   LogisticRegression @rec≥0.85(0.083)   0.083125  0.771182   0.213248  0.850613  0.341006     0.765241  0.985607  0.860341  0.359848
# 8            GradBoost @rec≥0.85(0.085)   0.084543  0.786778   0.225940  0.850613  0.357043     0.782003  0.985911  0.870859  0.337301
# 28            CatBoost @rec≥0.85(0.089)   0.089336  0.783287   0.222969  0.850613  0.353323     0.778250  0.985844  0.874974  0.351163
# 12       HistGradBoost @rec≥0.80(0.120)   0.119998  0.814323   0.245232  0.802676  0.375685     0.815195  0.982215  0.872083  0.310520
# 7            GradBoost @rec≥0.80(0.123)   0.123323  0.807107   0.237355  0.800446  0.366140     0.807606  0.981851  0.870859  0.337301
# 27            CatBoost @rec≥0.80(0.127)   0.127300  0.810599   0.240940  0.800446  0.370389     0.811359  0.981934  0.874974  0.351163
# 22             XGBoost @rec≥0.80(0.129)   0.129314  0.818824   0.249826  0.800446  0.380801     0.820198  0.982125  0.871885  0.323971
# 2   LogisticRegression @rec≥0.80(0.132)   0.131779  0.814556   0.245135  0.800446  0.375327     0.815612  0.982026  0.860341  0.359848
# 18        RandomForest @rec≥0.85(0.136)   0.136072  0.772734   0.214446  0.850613  0.342536     0.766909  0.985638  0.870344  0.358397
# 34                 KNN @rec≥0.90(0.158)   0.157598  0.617396   0.143135  0.901895  0.247061     0.596114  0.987839  0.837140  0.227168
# 6            GradBoost @rec≥0.70(0.175)   0.175247  0.832790   0.251972  0.712375  0.372269     0.841798  0.975077  0.870859  0.337301
# 17        RandomForest @rec≥0.80(0.179)   0.179160  0.801909   0.232039  0.799331  0.359669     0.802102  0.981629  0.870344  0.358397
# 5            GradBoost @rec≥0.65(0.184)   0.184388  0.834109   0.242638  0.652174  0.353688     0.847719  0.970220  0.870859  0.337301
# 26            CatBoost @rec≥0.70(0.187)   0.186578  0.834808   0.252412  0.700111  0.371049     0.844884  0.974135  0.874974  0.351163
# 1   LogisticRegression @rec≥0.70(0.199)   0.198858  0.828445   0.245940  0.709030  0.365202     0.837378  0.974665  0.860341  0.359848
# 21             XGBoost @rec≥0.70(0.201)   0.200629  0.841946   0.262104  0.700111  0.381415     0.852556  0.974361  0.871885  0.323971
# 11       HistGradBoost @rec≥0.70(0.201)   0.200980  0.838920   0.257906  0.700111  0.376951     0.849304  0.974266  0.872083  0.310520
# 33                 KNN @rec≥0.85(0.203)   0.203473  0.676986   0.159224  0.850613  0.268237     0.663998  0.983449  0.837140  0.227168
# 16        RandomForest @rec≥0.70(0.216)   0.216000  0.833799   0.251100  0.700111  0.369629     0.843800  0.974102  0.870344  0.358397
# 25            CatBoost @rec≥0.65(0.221)   0.221177  0.864758   0.289970  0.651059  0.401237     0.880744  0.971216  0.874974  0.351163
# 20             XGBoost @rec≥0.65(0.222)   0.222193  0.845360   0.259015  0.656633  0.371492     0.859478  0.970982  0.871885  0.323971
# 10       HistGradBoost @rec≥0.65(0.222)   0.222330  0.845903   0.258751  0.651059  0.370323     0.860479  0.970558  0.872083  0.310520
# 0   LogisticRegression @rec≥0.65(0.226)   0.225591  0.850636   0.265938  0.651059  0.377627     0.865566  0.970726  0.860341  0.359848
# 32                 KNN @rec≥0.80(0.237)   0.236843  0.742551   0.186155  0.800446  0.302061     0.738220  0.980179  0.837140  0.227168
# 15        RandomForest @rec≥0.65(0.242)   0.241749  0.856068   0.274482  0.649944  0.385965     0.871487  0.970829  0.870344  0.358397
# 31                 KNN @rec≥0.70(0.305)   0.305145  0.844584   0.265876  0.700111  0.385394     0.855392  0.974444  0.837140  0.227168
# 30                 KNN @rec≥0.65(0.331)   0.331288  0.851878   0.268315  0.653289  0.380396     0.866733  0.970945  0.837140  0.227168
# 36          NaiveBayes @rec≥0.70(0.566)   0.565826  0.802374   0.216105  0.700111  0.330266     0.810024  0.973051  0.833260  0.288609
# 35          NaiveBayes @rec≥0.65(0.913)   0.912569  0.832480   0.240329  0.651059  0.351067     0.846051  0.970071  0.833260  0.288609
# Saved recall-targeted thresholds: /Users/hasnainali/Documents/breastcancer/best_models_no_smote_weights/chosen_thresholds.json

# %%
TARGET = 0.65  # change to 0.90 if you want even higher recall
with open(outdir / "chosen_thresholds.json") as f:
    THS = json.load(f)

rows = []
for name, est in available.items():
    thr = THS[name][f"recall≥{TARGET:.2f}"]
    rows.append(eval_on_test(name, est, X_test, y_test, w=W_test, thr=thr))

table_same_recall = pd.DataFrame(rows).sort_values("precision", ascending=False)
display(table_same_recall)
# Out:
#                 model  threshold  accuracy  precision    recall        f1  specificity       npv   roc_auc    pr_auc
# 5            CatBoost   0.221177  0.864758   0.289970  0.651059  0.401237     0.880744  0.971216  0.874974  0.351163
# 3        RandomForest   0.241749  0.856068   0.274482  0.649944  0.385965     0.871487  0.970829  0.870344  0.358397
# 6                 KNN   0.331288  0.851878   0.268315  0.653289  0.380396     0.866733  0.970945  0.837140  0.227168
# 0  LogisticRegression   0.225591  0.850636   0.265938  0.651059  0.377627     0.865566  0.970726  0.860341  0.359848
# 4             XGBoost   0.222193  0.845360   0.259015  0.656633  0.371492     0.859478  0.970982  0.871885  0.323971
# 2       HistGradBoost   0.222330  0.845903   0.258751  0.651059  0.370323     0.860479  0.970558  0.872083  0.310520
# 1           GradBoost   0.184388  0.834109   0.242638  0.652174  0.353688     0.847719  0.970220  0.870859  0.337301
# 7          NaiveBayes   0.912569  0.832480   0.240329  0.651059  0.351067     0.846051  0.970071  0.833260  0.288609

# %%
import numpy as np, pandas as pd
from sklearn.metrics import confusion_matrix

def per_1000(est, Xt, yt, w, thr):
    proba = est.predict_proba(Xt)[:,1]
    yhat  = (proba >= thr).astype(int)
    cm = confusion_matrix(yt, yhat, sample_weight=w)
    tn, fp, fn, tp = cm.ravel()
    N = cm.sum()
    scale = 1000.0 / N
    return pd.Series({
        "TP/1000": tp*scale,
        "FP/1000": fp*scale,
        "FN/1000": fn*scale,
        "TN/1000": tn*scale
    })

TARGET = 0.85
perk = []
for name, est in available.items():
    thr = THS[name][f"recall≥{TARGET:.2f}"]
    s = per_1000(est, X_test, y_test, W_test, thr)
    s.name = name
    perk.append(s)
display(pd.DataFrame(perk).sort_values("TP/1000", ascending=False))
# Out:
#                       TP/1000     FP/1000    FN/1000     TN/1000
# LogisticRegression  59.202359  218.420236  10.397269  711.980137
# GradBoost           59.202359  202.824333  10.397269  727.576040
# HistGradBoost       59.202359  202.901924  10.397269  727.498448
# RandomForest        59.202359  216.868405  10.397269  713.531968
# XGBoost             59.202359  203.367474  10.397269  727.032899
# CatBoost            59.202359  206.315953  10.397269  724.084420
# KNN                 59.202359  312.616387  10.397269  617.783985
# NaiveBayes          59.202359  332.169460  10.397269  598.230912

# %% [markdown]
# ## Extra

# %%
# Paste this into a notebook cell and run (adjust column names & dataset path)
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline as SkPipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import precision_recall_curve, roc_auc_score, average_precision_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix


# --- define model and pipeline (SMOTE inside pipeline so over/under-sampling happens only in CV folds) ---
smote = SMOTE(random_state=42)

xgb = XGBClassifier(
    objective="binary:logistic", use_label_encoder=False, eval_metric="logloss",
    n_jobs=-1, random_state=42
)

pipeline = ImbPipeline([
    ("preprocess", preprocessor),
    ("smote", smote),
    ("clf", xgb)
])

# --- param distribution for RandomizedSearchCV ---
param_distributions = {
    "clf__n_estimators": [100, 200, 400],
    "clf__max_depth": [3, 5, 7],
    "clf__learning_rate": [0.01, 0.05, 0.1],
    "clf__subsample": [0.6, 0.8, 1.0],
    "clf__colsample_bytree": [0.6, 0.8, 1.0],
    # You can add reg_alpha/reg_lambda, min_child_weight etc.
}

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

search = RandomizedSearchCV(
    estimator=pipeline,
    param_distributions=param_distributions,
    n_iter=30,
    scoring="average_precision",  # optimize PR-AUC directly
    n_jobs=-1,
    cv=cv,
    verbose=2,
    random_state=42,
    refit=True
)

# Fit (this will run CV; SMOTE applied only to train folds)
search.fit(X_train, y_train)

print("Best params:", search.best_params_)
print("Best cross-val average_precision (PR-AUC):", search.best_score_)

# --- Evaluate on hold-out test set using probabilities ---
best = search.best_estimator_
y_proba_test = best.predict_proba(X_test)[:, 1]

# chosen metric: average precision on test
test_ap = average_precision_score(y_test, y_proba_test)
roc_auc = roc_auc_score(y_test, y_proba_test)
print("Test average_precision (PR-AUC):", test_ap)
print("Test ROC-AUC:", roc_auc)

# --- threshold selection (choose threshold that maximizes F1 on validation within CV or using a validation split) ---
precisions, recalls, thresholds = precision_recall_curve(y_test, y_proba_test)
f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-12)
best_idx = np.nanargmax(f1_scores)
best_thresh = thresholds[best_idx] if best_idx < len(thresholds) else 0.5
print("Best threshold by F1 on test (not recommended - better choose via CV):", best_thresh)

y_pred_thresh = (y_proba_test >= best_thresh).astype(int)

metrics = {
    "accuracy": accuracy_score(y_test, y_pred_thresh),
    "precision": precision_score(y_test, y_pred_thresh, zero_division=0),
    "recall": recall_score(y_test, y_pred_thresh, zero_division=0),
    "f1": f1_score(y_test, y_pred_thresh, zero_division=0),
    "roc_auc": roc_auc_score(y_test, y_proba_test),
    "pr_auc": average_precision_score(y_test, y_proba_test)
}
print(metrics)
print("Confusion matrix:\n", confusion_matrix(y_test, y_pred_thresh))
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /opt/anaconda3/lib/python3.13/site-packages/xgboost/training.py:183: UserWarning: [19:08:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Best params: {'clf__subsample': 0.6, 'clf__n_estimators': 400, 'clf__max_depth': 7, 'clf__learning_rate': 0.01, 'clf__colsample_bytree': 0.6}
# Best cross-val average_precision (PR-AUC): 0.48459226830242985
# Test average_precision (PR-AUC): 0.4792644043563937
# Test ROC-AUC: 0.8188745017604078
# Best threshold by F1 on test (not recommended - better choose via CV): 0.41487387
# {'accuracy': 0.7937841243175137, 'precision': 0.46063651591289784, 'recall': 0.6193693693693694, 'f1': 0.5283381364073007, 'roc_auc': np.float64(0.8188745017604078), 'pr_auc': np.float64(0.4792644043563937)}
# Confusion matrix:
#  [[1615  322]
#  [ 169  275]]

# %% [markdown]
# # 24) Preprocessing Fixes (sparse_output + safe categorical impute)

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline as SkPipeline
import numpy as np

def to_str_df(X):
    X = X.copy()
    for c in CATEGORICAL_COLS:
        if c in X.columns:
            X[c] = X[c].astype(str)
    return X

num_tf = SkPipeline([('imputer', SimpleImputer(strategy='median')),
                     ('scaler', StandardScaler())])
cat_tf = SkPipeline([('to_str', FunctionTransformer(to_str_df)),
                     ('imputer', SimpleImputer(strategy='most_frequent')),
                     ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))])
preprocessor = ColumnTransformer([('num', num_tf, NUMERIC_COLS),
                                  ('cat', cat_tf, CATEGORICAL_COLS)], remainder='drop')
print("Rebuilt preprocessor with dense OHE and safe categorical handling.")

# %% [markdown]
# # 25) Tune RandomForest (PR-AUC)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
smote = SMOTE(random_state=RANDOM_STATE, n_jobs=-1)

rf = RandomForestClassifier(n_jobs=-1, random_state=RANDOM_STATE, class_weight='balanced')
rf_space = {"clf__n_estimators":[400,600,800],"clf__max_depth":[None,8,12,16],"clf__min_samples_split":[2,5,10],"clf__min_samples_leaf":[1,2,4],"clf__max_features":["sqrt","log2",None]}
rf_pipe = ImbPipeline([('preprocess', preprocessor), ('sampler', smote), ('clf', rf)])
rf_search = RandomizedSearchCV(rf_pipe, rf_space, n_iter=25, scoring='average_precision', cv=cv, n_jobs=-1, random_state=RANDOM_STATE, verbose=1, refit=True)
rf_search.fit(X_train, y_train)
RF_best = rf_search.best_estimator_
print("RF best PR-AUC (CV):", round(rf_search.best_score_,6))
print(rf_search.best_params_)

# %% [markdown]
# # 26) Tune GradientBoosting (PR-AUC)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(random_state=RANDOM_STATE)
gb_space = {"clf__n_estimators":[200,300,500],"clf__learning_rate":[0.03,0.05,0.1],"clf__max_depth":[2,3,4],"clf__subsample":[0.6,0.8,1.0]}
gb_pipe = ImbPipeline([('preprocess', preprocessor), ('sampler', smote), ('clf', gb)])
gb_search = RandomizedSearchCV(gb_pipe, gb_space, n_iter=20, scoring='average_precision', cv=cv, n_jobs=-1, random_state=RANDOM_STATE, verbose=1, refit=True)
gb_search.fit(X_train, y_train)
GB_best = gb_search.best_estimator_
print("GB best PR-AUC (CV):", round(gb_search.best_score_,6))
print(gb_search.best_params_)

# %% [markdown]
# # 27) Tune XGBoost (PR-AUC)

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier(objective="binary:logistic", eval_metric="logloss", n_jobs=-1, random_state=RANDOM_STATE)
xgb_space = {"clf__n_estimators":[400,600,800],"clf__learning_rate":[0.01,0.03,0.05,0.1],"clf__max_depth":[3,4,5,6],"clf__subsample":[0.6,0.8,1.0],"clf__colsample_bytree":[0.6,0.8,1.0],"clf__reg_lambda":[0.5,1.0,2.0,5.0],"clf__reg_alpha":[0.0,0.5,1.0]}
xgb_pipe = ImbPipeline([('preprocess', preprocessor), ('sampler', smote), ('clf', xgb)])
xgb_search = RandomizedSearchCV(xgb_pipe, xgb_space, n_iter=30, scoring="average_precision", cv=cv, n_jobs=-1, random_state=RANDOM_STATE, verbose=1, refit=True)
xgb_search.fit(X_train, y_train)
XGB_best = xgb_search.best_estimator_
print("XGB best PR-AUC (CV):", round(xgb_search.best_score_,6))
print(xgb_search.best_params_)

# %% [markdown]
# # 28) Tune CatBoost (PR-AUC)

# %%
try:
    from catboost import CatBoostClassifier
    cat = CatBoostClassifier(loss_function="Logloss", verbose=False, random_seed=RANDOM_STATE, thread_count=-1, allow_writing_files=False)
    cat_space = {"clf__depth":[4,6,8],"clf__learning_rate":[0.03,0.05,0.1],"clf__iterations":[400,600,800],"clf__l2_leaf_reg":[1,3,5,7]}
    cat_pipe = ImbPipeline([('preprocess', preprocessor), ('sampler', smote), ('clf', cat)])
    cat_search = RandomizedSearchCV(cat_pipe, cat_space, n_iter=25, scoring="average_precision", cv=cv, n_jobs=-1, random_state=RANDOM_STATE, verbose=1, refit=True)
    cat_search.fit(X_train, y_train)
    CAT_best = cat_search.best_estimator_
    print("CAT best PR-AUC (CV):", round(cat_search.best_score_,6))
    print(cat_search.best_params_)
except Exception as e:
    CAT_best = None
    print("CatBoost not available:", e)

# %% [markdown]
# # 29) Compare Tuned Best Models on Hold‑Out

# %%
from sklearn.metrics import average_precision_score, roc_auc_score
import pandas as pd
best_models = {'RandomForest': RF_best, 'GradientBoosting': GB_best, 'XGBoost': XGB_best}
if CAT_best is not None: best_models['CatBoost'] = CAT_best
rows = []
for name, model in best_models.items():
    model.fit(X_train, y_train)
    y_proba = model.predict_proba(X_test)[:,1]
    rows.append((name, average_precision_score(y_test, y_proba), roc_auc_score(y_test, y_proba)))
compare_best_df = pd.DataFrame(rows, columns=['Model','Holdout_PR_AUC','Holdout_ROC_AUC']).sort_values('Holdout_PR_AUC', ascending=False)
display(compare_best_df)
